# %%
import pandas as pd

x_train = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/studentscore/X_train.csv')
y_train = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/studentscore/y_train.csv')
x_test = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/studentscore/X_test.csv')
y_test = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/studentscore/y_test.csv')

# %%
drop_columns = ['StudentID']

x_train_drop = x_train.drop(columns=drop_columns)
x_test_drop = x_test.drop(columns=drop_columns)

# %%
x_train_d = pd.get_dummies(x_train_drop)
x_test_d = pd.get_dummies(x_test_drop)[x_train_d.columns]

# %%
y_train_t = y_train['G3']
y_test_t = y_test['G3']

# %%
from sklearn.model_selection import train_test_split

X_t, X_v, y_t, y_v = train_test_split(x_train_d, y_train_t, test_size=0.33, random_state=42)

# %%
from sklearn.ensemble import RandomForestRegressor

rfr = RandomForestRegressor(random_state=23)
rfr.fit(X_t, y_t)
# Out:
# RandomForestRegressor(random_state=23)

# %%
ptl = rfr.predict(X_t)
pvl = rfr.predict(X_v)

# %%
# 모델평가
# mse : mean_squared_error / mae : mean_absolute_error  / mape : mean_absolute_percentage_error
# rmse : root_mean_squerd_error -> 패키지 없음 np.sqrt(mean_squared_error) 해줘야함
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
import numpy as np

print(f'train mse : {mean_squared_error(y_t, ptl)}')
print(f'train mae : {mean_absolute_error(y_t, ptl)}')
print(f'train mape : {mean_absolute_percentage_error(y_t, ptl)}')
print(f'train rmse : {np.sqrt(mean_squared_error(y_t, ptl))}')
print(f'train r2 score : {r2_score(y_t, ptl)}')

print(f'validation mse : {mean_squared_error(y_v, pvl)}')
print(f'validation mae : {mean_absolute_error(y_v, pvl)}')
print(f'validation mape : {mean_absolute_percentage_error(y_v, pvl)}')
print(f'validation rmse : {np.sqrt(mean_squared_error(y_v, pvl))}')
print(f'validation r2 score : {r2_score(y_v, pvl)}')
# Out:
# train mse : 0.2879515418502203
# train mae : 0.33383259911894275
# train mape : 259403370607353.47
# train rmse : 0.536611164485254
# train r2 score : 0.981014544398353
# validation mse : 2.197141964285714
# validation mae : 0.9666071428571428
# validation mape : 497808601668274.5
# validation rmse : 1.4822759406688466
# validation r2 score : 0.8385640615321535

# %%
p_test_l = rfr.predict(x_test_d)

print(f'test mse : {mean_squared_error(y_test_t, p_test_l)}')
print(f'test mae : {mean_absolute_error(y_test_t, p_test_l)}')
print(f'test mape : {mean_absolute_percentage_error(y_test_t, p_test_l)}')
print(f'test rmse : {np.sqrt(mean_squared_error(y_test_t, p_test_l))}')
print(f'test r2 score : {r2_score(y_test_t, p_test_l)}')
# Out:
# test mse : 2.668798633879782
# test mae : 0.9658196721311476
# test mape : 706179187472111.4
# test rmse : 1.6336458104129492
# test r2 score : 0.8264474510462623
